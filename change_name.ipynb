# %%
import os

# %%
dir = r'C:\Users\mathe\Desktop\projetos em python\ML\k-means_figuras\elefante'
arquivos = os.listdir(dir)
arquivos
# Out:
# ['e032b10b2df21c22d2524518b7444f92e37fe5d404b0144390f8c07aa5ecb6_640.jpg',
#  'e130b80b2ef11c22d2524518b7444f92e37fe5d404b0144390f8c07aa4e5b0_640.jpg',
#  'e131b0072ee90021d85a5854ee454296eb70e3c818b413449df1c27ba6ee_640.jpg',
#  'e132b10a2bf51c22d2524518b7444f92e37fe5d404b0144390f8c07aa4e5b0_640.jpg',
#  'e133b10d2bf21c22d2524518b7444f92e37fe5d404b0144390f8c07aa4e5b0_640.jpg',
#  'e133b5062cf71c22d2524518b7444f92e37fe5d404b0144390f8c07aa4e5b0_640.jpg',
#  'e135b0062efc1c22d2524518b7444f92e37fe5d404b0144390f8c07aa4e5b0_640.jpg',
#  'e135b10f21f61c22d2524518b7444f92e37fe5d404b0144390f8c07aa4e5b0_640.jpg',
#  'e830b3092ff4083ed1584d05fb1d4e9fe777ead218ac104497f5c978a4efb4bb_640.jpg',
#  'e830b8062ff2023ed1584d05fb1d4e9fe777ead218ac104497f5c978a4eebdbd_640.jpg',
#  'e831b30e29f2063ed1584d05fb1d4e9fe777ead218ac104497f5c978a4efb4bb_640.jpg',
#  'e831b30e2af2043ed1584d05fb1d4e9fe777ead218ac104497f5c978a4efbcb0_640.jpg',
# ...

# %%
j=1262
for i in arquivos:
    old_file = os.path.join(dir, i)
    new_file = os.path.join(dir, str(j)+'.jpg')
    os.rename(old_file, new_file)
    j += 1
